# %%
import torch
import util
x = torch.load('cust_6SSW/dist')
util.plot_image(x)

# %%
x = util.distm_pdb('af2_6SSW.pdb')
util.plot_image(x)

# %%
x = torch.load('af2_6SSW/confidence_mask')
util.plot_image(x)
